# %%
# %run visualisation.ipynb
# %run read_graph.ipynb
# %run GirvanNewmanAlgorithms.ipynb
# %run CONGAYearAlgorithm.ipynb
# %run PrintCONGA.ipynb
g = read_nba_full("../Scrapers/BasketballReferenceScraper/data/Players.csv",
                  "../Scrapers/BasketballReferenceScraper/data/Edges.csv",
                  True, True)
# Out:
# Reading full NBA graph, begin...
# Reading file ../Scrapers/BasketballReferenceScraper/data/Players.csv, begin...
# Data lines read: 4800
# Reading file ../Scrapers/BasketballReferenceScraper/data/Edges.csv, begin...
# Data lines read: 146369
# Reading NBA vertices, begin...
# Vertices read: 4800
# Reading NBA edges, begin...
# Weights loaded correctly
# Edges read: 146369
# Loading succesfull

# %%
AllStars1920 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159]
Overlap = [-1 for i in range(0, 10*len(AllStars1920))]
result = []
AllStars1920Graph = g.subgraph(AllStars1920)
print(AllStars1920Graph.ecount())
print(AllStars1920Graph.vcount())

CONGAYearAlgorithm(AllStars1920Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars1920Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars1920)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 38
# 39
# Plotting graph with 39 vertices and 19 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 23 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 25 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 31 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 32 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 33 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 33 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 34 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 35 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 36 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 37 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 37 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 37 edges, begin...
# Plotting sucessful
# Plotting graph with 39 vertices and 37 edges, begin...
# Plotting sucessful

# %%
AllStars18_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586]
Overlap = [-1 for i in range(0, 10*len(AllStars18_20))]
result = []
AllStars18_20Graph = g.subgraph(AllStars18_20)
print(AllStars18_20Graph.ecount())
print(AllStars18_20Graph.vcount())

CONGAYearAlgorithm(AllStars18_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars18_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars18_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 66
# 48
# Plotting graph with 48 vertices and 24 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 32 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 44 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 45 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 46 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 48 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 49 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 53 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 54 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 56 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 56 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 58 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 60 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 60 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 61 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 62 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 63 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 63 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 63 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 63 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 64 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 64 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 64 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 64 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 64 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 64 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 65 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 65 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 65 edges, begin...
# Plotting sucessful
# Plotting graph with 48 vertices and 66 edges, begin...
# Plotting sucessful

# %%
AllStars17_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586,4198,115,2925,1459,2235,1794]
Overlap = [-1 for i in range(0, 10*len(AllStars17_20))]
result = []
AllStars17_20Graph = g.subgraph(AllStars17_20)
print(AllStars17_20Graph.ecount())
print(AllStars17_20Graph.vcount())

CONGAYearAlgorithm(AllStars17_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars17_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars17_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 98
# 54
# Plotting graph with 54 vertices and 42 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 46 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 66 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 68 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 70 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 76 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 77 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 77 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 78 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 84 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 86 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 86 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 87 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 88 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 89 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 91 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 92 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 92 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 92 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 93 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 94 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 94 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 94 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 94 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 94 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 95 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 96 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 54 vertices and 98 edges, begin...
# Plotting sucessful

# %%
AllStars16_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586,4198,115,2925,1459,2235,1794,415,1460,564]
Overlap = [-1 for i in range(0, 10*len(AllStars16_20))]
result = []
AllStars16_20Graph = g.subgraph(AllStars16_20)
print(AllStars16_20Graph.ecount())
print(AllStars16_20Graph.vcount())

CONGAYearAlgorithm(AllStars16_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars16_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars16_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 111
# 57
# Plotting graph with 57 vertices and 40 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 44 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 62 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 65 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 69 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 76 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 80 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 82 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 87 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 88 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 94 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 96 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 96 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 96 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 97 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 98 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 99 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 100 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 102 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 103 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 105 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 105 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 105 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 106 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 106 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 106 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 106 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 108 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 109 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 110 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 57 vertices and 111 edges, begin...
# Plotting sucessful

# %%
AllStars15_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586,4198,115,2925,1459,2235,1794,415,1460,564,4168,2384,1142,]
Overlap = [-1 for i in range(0, 10*len(AllStars15_20))]
result = []
AllStars15_20Graph = g.subgraph(AllStars15_20)
print(AllStars15_20Graph.ecount())
print(AllStars15_20Graph.vcount())

CONGAYearAlgorithm(AllStars15_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars15_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars15_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 133
# 60
# Plotting graph with 60 vertices and 43 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 49 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 57 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 77 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 83 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 87 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 88 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 92 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 93 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 95 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 95 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 102 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 103 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 104 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 105 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 110 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 111 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 113 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 113 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 113 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 114 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 114 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 115 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 115 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 116 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 116 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 118 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 118 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 119 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 119 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 119 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 120 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 120 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 121 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 121 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 122 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 123 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 124 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 125 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 126 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 127 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 128 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 128 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 128 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 131 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 131 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 132 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 60 vertices and 133 edges, begin...
# Plotting sucessful

# %%
AllStars14_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586,4198,115,2925,1459,2235,1794,415,1460,564,4168,2384,1142,3134,1849,2145,1945,3283]
Overlap = [-1 for i in range(0, 10*len(AllStars14_20))]
result = []
AllStars14_20Graph = g.subgraph(AllStars14_20)
print(AllStars14_20Graph.ecount())
print(AllStars14_20Graph.vcount())

CONGAYearAlgorithm(AllStars14_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars14_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars14_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 169
# 65
# Plotting graph with 65 vertices and 65 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 71 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 91 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 107 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 110 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 112 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 113 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 121 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 121 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 129 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 132 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 133 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 134 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 134 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 134 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 134 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 135 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 136 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 137 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 139 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 141 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 143 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 143 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 143 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 143 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 144 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 145 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 146 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 148 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 150 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 150 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 151 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 151 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 151 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 152 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 153 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 154 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 155 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 155 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 156 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 156 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 158 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 159 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 159 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 159 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 159 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 159 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 160 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 161 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 162 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 162 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 163 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 163 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 164 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 164 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 164 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 164 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 164 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 164 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 166 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 167 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 167 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 168 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 65 vertices and 169 edges, begin...
# Plotting sucessful

# %%
AllStars13_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586,4198,115,2925,1459,2235,1794,415,1460,564,4168,2384,1142,3134,1849,2145,1945,3283,3669,1446,718,1031,1898,2577,2492,3502]
Overlap = [-1 for i in range(0, 10*len(AllStars13_20))]
result = []
AllStars13_20Graph = g.subgraph(AllStars13_20)
print(AllStars13_20Graph.ecount())
print(AllStars13_20Graph.vcount())

CONGAYearAlgorithm(AllStars13_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars13_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars13_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 231
# 73
# Plotting graph with 73 vertices and 96 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 102 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 130 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 132 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 136 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 150 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 156 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 160 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 169 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 170 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 172 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 172 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 172 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 172 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 172 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 173 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 178 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 179 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 180 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 181 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 181 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 182 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 189 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 190 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 190 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 190 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 192 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 192 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 192 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 192 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 192 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 193 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 194 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 195 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 195 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 195 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 197 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 198 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 199 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 200 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 201 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 202 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 202 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 203 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 203 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 204 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 205 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 207 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 207 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 207 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 208 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 209 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 210 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 210 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 211 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 212 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 212 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 213 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 214 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 214 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 214 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 214 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 214 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 214 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 214 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 215 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 215 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 215 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 216 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 217 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 218 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 218 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 219 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 219 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 219 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 219 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 219 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 220 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 221 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 221 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 221 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 222 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 222 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 224 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 224 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 224 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 224 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 225 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 225 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 226 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 226 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 226 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 226 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 226 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 227 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 227 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 228 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 228 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 228 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 230 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 73 vertices and 231 edges, begin...
# Plotting sucessful

# %%
AllStars12_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586,4198,115,2925,1459,2235,1794,415,1460,564,4168,2384,1142,3134,1849,2145,1945,3283,3669,1446,718,1031,1898,2577,2492,3502,620,3079,3672,1995,3383,4609]
Overlap = [-1 for i in range(0, 10*len(AllStars12_20))]
result = []
AllStars12_20Graph = g.subgraph(AllStars12_20)
AllStars12_20Graph.simplify(multiple=False, loops=True, combine_edges=None)
print(AllStars12_20Graph.ecount())
print(AllStars12_20Graph.vcount())

CONGAYearAlgorithm(AllStars12_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars12_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars12_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 291
# 79
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 291
# 1 -1 1
# 3 1 1
# 2 3 0
# 3 2 0
# 2 3 0
# 3 2 0
# 3 3 0
# 3 3 0
# 3 3 0
# 3 3 0
# 3 3 0
#
# 294 [187, 189, 191]
# 36 83
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 278
# 3 -1 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
#
# 279 [269]
# 95 185
# 278
# 3 -1 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
#
# 279 [145]
# 117 129
# 278
# 3 -1 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
#
# 279 [124]
# 117 119
# 278
# 3 -1 1
# 3 3 1
# 3 3 1
# 3 3 1
# 3 3 1
#
# 279 [120]
# 2 118
#
#
# 278
# 3 -1 1
# 3 3 1
# 3 3 1
# 3 3 1
#
# 279 [82]
# 37 96
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Plotting graph with 79 vertices and 108 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 126 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 166 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 200 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 206 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 212 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 215 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 215 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 216 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 217 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 218 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 218 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 226 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 228 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 242 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 244 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 245 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 245 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 245 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 246 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 247 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 247 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 247 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 248 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 249 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 257 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 258 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 259 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 259 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 259 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 261 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 261 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 262 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 262 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 262 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 262 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 262 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 263 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 265 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 265 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 266 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 267 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 269 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 269 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 272 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 273 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 273 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 273 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 273 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 273 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 274 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 274 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 274 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 274 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 276 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 277 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 278 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 279 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 279 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 279 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 280 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 281 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 282 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 283 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 284 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 284 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 284 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 287 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 289 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 289 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 290 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 290 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful
# Plotting graph with 79 vertices and 291 edges, begin...
# Plotting sucessful

# %%
AllStars11_20 = [4524, 4418, 4778, 112, 3876, 1223, 2591, 3892, 614, 2889, 25, 4147, 3726, 1717, 1085, 2065, 2513, 955, 3311, 2542, 2938, 2004, 2177, 1517, 401, 2009, 3201, 266, 1620, 4393, 4396, 3719, 921, 1149, 1475, 4227, 44, 4278, 3159, 1038, 1113, 1929, 3429, 4432, 1125, 863, 1588, 2586,4198,115,2925,1459,2235,1794,415,1460,564,4168,2384,1142,3134,1849,2145,1945,3283,3669,1446,718,1031,1898,2577,2492,3502,620,3079,3672,1995,3383,4609,4090,65,2930,1504]
Overlap = [-1 for i in range(0, 10*len(AllStars11_20))]
result = []
AllStars11_20Graph = g.subgraph(AllStars11_20)
print(AllStars11_20Graph.ecount())
print(AllStars11_20Graph.vcount())

CONGAYearAlgorithm(AllStars11_20Graph, result, Overlap)
#print(result)
#print(Overlap)

resultGraph = AllStars11_20Graph.copy()
#print(resultGraph.ecount())
#print(resultGraph.vcount())
toPrint = g.subgraph(AllStars11_20)
while toPrint.ecount() > 0:
    for edge in toPrint.es:
        toPrint.delete_edges(edge)
#print(toPrint.ecount())
#print(toPrint.vcount())

test = PrintGraph(resultGraph, toPrint, result, Overlap, len(result),1)
# Out:
# 315
# 83
# Plotting graph with 83 vertices and 109 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 121 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 157 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 159 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 163 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 217 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 223 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 229 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 230 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 231 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 235 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 236 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 237 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 238 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 239 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 240 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 241 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 242 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 242 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 242 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 252 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 260 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 261 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 270 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 271 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 272 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 273 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 274 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 274 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 275 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 276 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 276 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 278 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 278 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 279 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 279 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 280 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 282 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 282 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 282 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 284 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 285 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 286 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 288 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 290 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 290 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 290 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 290 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 292 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 294 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 295 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 296 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 296 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 296 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 297 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 297 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 298 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 298 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 298 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 299 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 301 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 302 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 303 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 304 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 305 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 305 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 306 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 306 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 306 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 307 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 307 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 308 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 309 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 310 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 311 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 312 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 312 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 312 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 312 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 313 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 313 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 313 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 313 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 314 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
# Plotting graph with 83 vertices and 315 edges, begin...
# Plotting sucessful
